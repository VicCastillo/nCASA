# %%
##This classifier uses MFCC coeffecients as features for the classification
##Classification classes are different types of birds
##Classifier is a Gaussian Mixed-Model Classifier
##Modelled after this paper:
##http://www.jeroenbreebaart.com/papers/soia/soia2004.pdf

# %%
import numpy as np
from numpy import sin, linspace, pi
from numpy.fft import fftfreq
import scipy as sp
from scipy import fft, arange
from scipy.io.wavfile import read, write
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from __future__ import division
from matplotlib.pyplot import specgram


from features import mfcc
from features import logfbank
import scipy.io.wavfile as wav

# %%
##Getting MFCC from a .wav file

# sound data file directory
datadir = "/Users/ksk/ncasa/"

#sound files
cardinalfile = datadir + 'cardinal.wav'

wavedata = read(cardinalfile)

# %%
#import scipy, pylab

def stft(x, fs, framesamp, hopsamp):
    w = sp.hamming(framesamp)
    X = sp.array([sp.fft(w*x[i:i+framesamp]) 
                     for i in range(0, len(x)-framesamp, hopsamp)])
    return X

def istft(X, fs, T, hopsamp):
    x = sp.zeros(T*fs)
    framesamp = 128 #X.shape[1]
    for n,i in enumerate(range(0, len(x)-framesamp, hopsamp)):
        x[i:i+framesamp] += sp.real(sp.ifft(X[n]))
    return x

def plot_time(signal):
    plt.figure(figsize=(20,3))
    plt.plot(signal)
    plt.xlabel("Samples")
    plt.show()

    ##Need to redo scaling for tick labels
def colorarray(specArray):
    maxpower = np.amax(specArray)
    plt.figure(figsize=(15,10))
    plt.xlabel("Time(sec)")
    plt.ylabel("Freq(Hz)")

    #xlocs,xlabs = plt.xticks() 
    #ylocs,ylabs = plt.yticks()
    #plt.yticks(ylocs,ylocs.__mul__(440/14).round(2))
    plt.pcolor(specArray.__div__(maxpower))
    plt.colorbar()
    print "Color plot of spectral-temporal data matrix: "

# %%
fs = wavedata[0] #sample rate
x  = wavedata[1] #time series
plot_time(x)

X = stft(x, fs, 128, 64) #transform into frequency domain

##Squaring real and imaginary components and taking square root

Xnew = np.sqrt(X.real**2 + X.imag**2)
colorarray(Xnew.T)

nsamples = 40879
T = nsamples/fs
xnew = istft(X, fs, T, 64) #transfer back ingto time domain

xnewint = xnew.astype(np.int16)
plot_time(xnewint)

print X.shape
# Out:
# Color plot of spectral-temporal data matrix:
# (637, 128)

# %%
##MFCC for very specific Freq ranges

#between 0 and 15Hz
zero15 = mfcc(wavedata[1], samplerate=fs, winlen=.2,winstep=.11, lowfreq=0, highfreq=15)

fifteen40 = mfcc(wavedata[1], samplerate=fs, winlen=.2,winstep=.11, lowfreq=15, highfreq=40)

forty90 = mfcc(wavedata[1], samplerate=fs, winlen=.2,winstep=.11, lowfreq=40, highfreq=90)

ninety120 = mfcc(wavedata[1], samplerate=fs, winlen=.2,winstep=.11, lowfreq=90, highfreq=120)
# Out:
# array([[  1.51899382e+01,  -7.68676840e+00,  -5.60214902e+00,
#          -3.76018474e+00,  -5.86158714e+00,  -2.06759231e+00,
#          -2.97842122e+00,   1.91184630e+00,  -3.64143344e-01,
#          -1.58130494e+00,  -3.57205545e+00,   2.04988581e+00,
#           6.08524350e-01],
#        [  1.84944084e+01,  -1.79619745e+01,  -3.79790842e+01,
#           7.13215941e+00,   2.61041944e+01,  -8.50336616e+00,
#          -2.99183725e+01,   1.01420488e+01,   2.72399203e+01,
#          -2.24545586e+01,  -1.45165228e+01,   1.50324897e+01,
#           4.71996770e+00],
#        [  1.98719742e+01,  -2.76940751e+01,  -2.41502643e+01,
#           3.89576671e+01,  -1.92433595e+01,  -1.87328621e+01,
#           2.81434109e+01,  -1.59732059e+01,  -1.96651953e+00,
#          -2.40798364e+01,   3.65828219e+01,   6.37054387e+00,
#          -3.99006836e+01,   8.30784801e+00,   2.26460330e+01,
#          -7.00602969e+00],
#        [  2.29216123e+01,  -2.49153083e+01,  -2.54597315e+01,
#           5.36278501e+01,  -3.46610655e+01,  -1.37513628e+01,
#           3.49616928e+01,  -2.49980683e+01,  -2.23729514e-01,
#           1.08868478e+01,  -1.21528019e+01,   7.74612623e+00,
#          -2.87329750e+00],
#        [  1.53793460e+01,  -2.68232264e+01,  -2.68176604e+01,
#           1.41377440e+01,  -1.79775679e+01,  -9.52850373e+00,
#           1.86289227e+01,  -9.09923777e+00,   7.54812817e-01,
#           1.32266980e+01,   5.94833833e+00,   1.55405210e+01,
#           2.75247458e-01],
#        [  1.46670213e+01,  -2.20349424e+01,  -1.83202011e+01,
#          -1.15606207e+01,  -6.01864086e+00,   8.53421928e-01,
#          -9.72866241e-01,  -2.90509571e-01,   3.11553527e+00,
#           4.96344244e+00,   1.08177844e+00,   8.90724773e+00,
#          -1.35346498e-01],
#        [  1.46599408e+01,  -2.10672825e+01,  -1.60827613e+01,
#          -1.55527941e+01,  -5.22238618e+00,  -2.34418361e-01,
#           3.37919968e+00,  -4.84326611e+00,  -5.49227815e+00,
#          -5.90330860e+00,   6.09566015e-01,  -2.39841285e+00,
#          -9.06642994e-01],
#        [  1.46297333e+01,  -2.23492083e+01,  -1.82834569e+01,
#          -1.50463835e+01,  -1.01142710e+01,   1.07475928e+00,
#          -5.07426716e-01,  -6.41005318e+00,   1.55661931e-01,
#          -5.42321128e+00,   1.89582187e-01,   7.64670137e+00,
#          -1.35729710e+00],
#        [  2.08665499e+01,  -2.00222036e+01,  -2.84387832e+01,
#           4.54583559e+01,  -1.26381339e+01,  -3.42694825e+01,
#           3.28714695e+01,   2.97942861e+00,  -2.73388879e+01,
#           7.67697559e+00,   7.35895901e+00,  -1.53060506e+00,
#          -3.70737245e+00],
#        [  1.53590667e+01,  -2.69954208e+01,  -2.60554792e+01,
#           9.76985974e+00,  -6.12359453e+00,  -1.14960743e+01,
#           2.84506462e+01,   6.88695093e-01,  -2.31232085e+01,
#           1.08532701e+01,  -2.43306537e+00,  -6.46604340e+00,
#           1.25776693e+00],
#        [  2.19526336e+01,  -2.49697704e+01,  -5.96288835e+00,
#           2.66423343e+01,  -3.37142108e+01,   1.60636364e+01,
#           8.89199854e+00,  -2.71486443e+01,   2.20757817e+01,
#          -8.47119326e+00,  -1.40254790e+01,   2.26278106e+01,
#          -1.76868878e+01],
#        [  2.35258356e+01,  -1.66676634e+01,  -1.81072255e+01,
#           3.56079525e+01,  -2.57886510e+01,  -1.06163559e+01,
#           3.52006886e+01,  -3.10727505e+01,  -2.60136583e+00,
#           2.43488251e+01,  -2.20136837e+01,   1.92504004e-02,
#           1.28012989e+01],
#        [  1.86725224e+01,  -7.85492238e+00,  -2.41572874e+01,
#           3.16045040e+01,  -1.56246432e+01,  -1.69143155e+01,
#           2.91948399e+01,  -1.21876903e+01,  -1.73115239e+01,
#           2.25438136e+01,  -9.61848763e+00,  -1.20250427e+01,
#           1.29626877e+01],
#        [  1.47361379e+01,  -1.92410344e+01,  -2.27359628e+01,
#          -1.39189532e+01,  -7.85037342e+00,   4.43006679e+00,
#           1.56917665e+00,  -1.32857400e+01,  -3.69047663e+00,
#           7.94971753e+00,  -1.44926719e+00,  -2.01546789e-02,
#          -7.05736127e+00]])

# %%
# Out:
# int16
